# %% [markdown]
# # tket benchmarking example

# %% [markdown]
# Warning: This notebook is now deprecated for versions from 0.2.0 onwards, and is not going to be updated in ongoing releases.
#
# The aim of this example is to show how to run the IBM benchmarking circuits through tket. You will need both `pytket` and `pytket_qiskit` installed from pip before running this turoial. You will also need `pandas` to capture the data.
#
# The benchmarking circuits originated from https://github.com/iic-jku/ibm_qx_mapping/tree/master/examples, but there is a copy in pytket in the "benchmarking" folder. The initial circuits are written in QASM, meaning that they must be converted to tket's internal representation via Qiskit. Using this script we will compile these circuits through tket and then print a table to terminal containing analysis of the circuits post-compilation.
#
# First, begin by importing qiskit and pytket.

# %%
import qiskit
import pytket

# %% [markdown]
# We need access to Qiskit's `QuantumCircuit` and the `circuit_to_dag` converter, which will allow us to take the original QASM and retrieve a Qiskit DAGCircuit. There is then a pytket method `dagcircuit_to_tk` to convert this DAGCircuit to tket's internal representation. We also need the pytket method `coupling_to_arc` to convert IBM's architectures to the tket `Architecture` class for the use of routing.

# %%
from qiskit import QuantumCircuit

from pytket.extensions.qiskit import qiskit_to_tk

# %% [markdown]
# We need all of the required pytket equipment to allow us to perform clean-up transform passes, to route and to analyse the circuits. Lastly, we require the `pandas` module to hold our data, and
# `time` to benchmark compilation time per circuit.

# %%
from pytket.routing import Architecture, route
from pytket.transform import Transform
from pytket import OpType
import pandas
import time

# %% [markdown]
# The architectures used to benchmark for our routing paper were the IBMqx5 and IBMTokyo architectures. The architectures qx5 and Tokyo respectively are shown below (although the diagrams do not show the directedness of the coupling maps). These diagrams are from https://www.research.ibm.com/ibm-q/technology/devices/#ibmqx5. We will now define the coupling map representing both architectures. These will later be converted to directed graphs to be used by tket.
# ![alt text](IBMqx5Arc.png "Title")
# ![alt text](IBMTokyoArc.png "Title2")

# %%
ibm_devices = {
    "ibmqx5": {"edges": [(1, 0), (1, 2), (2, 3), (3, 4), 
    (3, 14), (5, 4), (6, 5), (6, 7), (6, 11), (7, 10), 
    (8, 7), (9, 8), (9, 10), (11, 10), (12, 5), (12, 11), 
    (12, 13), (13, 4), (13, 14), (15, 0), (15, 2), (15, 14)],
    "nodes": 16},
    "ibmq_20_tokyo": {"edges": [(0, 1), (0, 5), (1, 2), (1, 6), (1, 7), (2, 3), (2, 6),
    (2, 7), (3, 4), (3, 8), (3, 9), (4, 8), (4, 9), (5, 6), (5, 10), (5, 11), (6, 7),
    (6, 10), (6, 11), (7, 8), (7, 12), (7, 13), (8, 9), (8, 12), (8, 13), (9, 14), (10, 11),
    (10, 15), (11, 12), (11, 16), (11, 17), (12, 13), (12, 16), (12, 17), (13, 14), (13, 18),
    (13, 19), (14, 18), (14, 19), (15, 16), (16, 17), (17, 18), (18, 19)], "nodes": 20}
}

# %% [markdown]
# We shall now choose the device and create a directed graph for tket's routing to use.

# %%
device_name = 'ibmqx5' #'ibm_20_tokyo' ###Note: can also be ran using the Tokyo machine architecture
                                       ###      or with a user-defined coupling map
coupling_map = ibm_devices[device_name]["edges"]
directed_arc = Architecture(coupling_map)

# %% [markdown]
# We now define a method which takes in (1) a QASM file and (2) a directed graph architecture; it returns analysis of the circuit after our transform passes and routing procedure have been completed. It will also print out to terminal the time taken for all the transformations and routing to finish. Changing which optimisations are run in this method will trade off quality of the ouputs for time taken. For example, removing all optimisation passes and just running the routing procedure will give the fastest run time but may leave some redundant gates in the final circuit.

# %%
def getStats(filename, directed_arc):
    qc = QuantumCircuit.from_qasm_file(filename)
    tkcirc = qiskit_to_tk(qc)
    start_time = time.process_time()
    Transform.OptimisePhaseGadgets().apply(tkcirc)
    outcirc = route(tkcirc, directed_arc)
    # decompose swaps to CX gates and redirect CXs in wrong direction
    Transform.DecomposeSWAPtoCX().apply(outcirc)
    Transform.DecomposeCXDirected(directed_arc)
    # outcirc.redirect_CX_gates(directed_arc)
    Transform.OptimisePostRouting().apply(outcirc)
    
    time_elapsed = time.process_time() - start_time
    
    print("Compilation time for circuit " + str(filename) + ": " + str(time_elapsed) + "s")
    if outcirc.n_gates==0:
        return [0,0,0,0,0]
    ###Returns: [number of vertices, circuit depth, nubmer of CX gates, number of parallel slices of CX gates]
    return [outcirc.n_gates, outcirc.depth(), outcirc.n_gates_of_type(OpType.CX), 
            outcirc.depth_by_type(OpType.CX), time_elapsed]
    ###Note: the raw number of vertices in the circuits and the raw depth 
    ###      need to have the i/o vertices removed for fair comparisons

# %% [markdown]
# Lastly, we generate the table of input QASM filenames from a csv file using `pandas` and run the circuits through our compiler. The results are printed to terminal by default.

# %%
test_table = pandas.read_csv("benchmarking/IBMQConfig.csv",index_col=0)
test_table = test_table.sort_values(by='Depth in')

stat_table = pandas.DataFrame({})
total_time = 0

for i, (index, row) in enumerate(test_table.iterrows()):
    filename = row['Filename']
    new_stats = getStats(filename, directed_arc)
    total_time += new_stats[4] ###
    print("Time spent compiling so far: " + str(total_time))
    new_table_row = pandas.DataFrame.from_dict({index : new_stats}, 
    orient='index', columns=['Size out', 'Depth out', 'CX count out', 'CX depth out','Runtime'])
    stat_table = stat_table.append(new_table_row)

#stat_table.to_csv("BenchmarkTket.csv") ###Note: uncomment this line to print table to csv.
with pandas.option_context('display.max_rows', None):
    print(stat_table)
# Out:
# Compilation time for circuit benchmarking/ibmq/xor5_254.qasm: 0.008160999999999419s
# Time spent compiling so far: 0.008160999999999419
# Compilation time for circuit benchmarking/ibmq/graycode6_47.qasm: 0.004186999999999941s
# Time spent compiling so far: 0.01234799999999936
# Compilation time for circuit benchmarking/ibmq/ex1_226.qasm: 0.007171999999999734s
# Time spent compiling so far: 0.019519999999999094
# Compilation time for circuit benchmarking/ibmq/4gt11_84.qasm: 0.013974000000000153s
# Time spent compiling so far: 0.03349399999999925
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_20.qasm: 0.017885999999999846s
# Time spent compiling so far: 0.05137999999999909
# Compilation time for circuit benchmarking/ibmq/ex-1_166.qasm: 0.015552000000000454s
# Time spent compiling so far: 0.06693199999999955
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_22.qasm: 0.023397999999998476s
# Time spent compiling so far: 0.09032999999999802
# Compilation time for circuit benchmarking/ibmq/mod5d1_63.qasm: 0.01691000000000109s
# Time spent compiling so far: 0.10723999999999911
# Compilation time for circuit benchmarking/ibmq/ham3_102.qasm: 0.014309000000000793s
# Time spent compiling so far: 0.12154899999999991
# Compilation time for circuit benchmarking/ibmq/4gt11_83.qasm: 0.017898000000000636s
# Time spent compiling so far: 0.13944700000000054
# Compilation time for circuit benchmarking/ibmq/4gt11_82.qasm: 0.020642999999999745s
# Time spent compiling so far: 0.1600900000000003
# Compilation time for circuit benchmarking/ibmq/rd32-v0_66.qasm: 0.02180599999999977s
# Time spent compiling so far: 0.18189600000000006
# Compilation time for circuit benchmarking/ibmq/alu-v0_27.qasm: 0.02952900000000014s
# Time spent compiling so far: 0.2114250000000002
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_24.qasm: 0.029802000000000106s
# Time spent compiling so far: 0.2412270000000003
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_19.qasm: 0.0320210000000003s
# Time spent compiling so far: 0.2732480000000006
# Compilation time for circuit benchmarking/ibmq/mod5mils_65.qasm: 0.02849300000000099s
# Time spent compiling so far: 0.3017410000000016
# Compilation time for circuit benchmarking/ibmq/rd32-v1_68.qasm: 0.027499000000000606s
# Time spent compiling so far: 0.3292400000000022
# Compilation time for circuit benchmarking/ibmq/alu-v1_28.qasm: 0.03822800000000015s
# Time spent compiling so far: 0.36746800000000235
# Compilation time for circuit benchmarking/ibmq/alu-v2_33.qasm: 0.03325999999999851s
# Time spent compiling so far: 0.40072800000000086
# Compilation time for circuit benchmarking/ibmq/alu-v4_37.qasm: 0.031821000000000765s
# Time spent compiling so far: 0.4325490000000016
# Compilation time for circuit benchmarking/ibmq/alu-v3_35.qasm: 0.03498899999999949s
# Time spent compiling so far: 0.4675380000000011
# Compilation time for circuit benchmarking/ibmq/3_17_13.qasm: 0.028131000000000128s
# Time spent compiling so far: 0.49566900000000125
# Compilation time for circuit benchmarking/ibmq/alu-v1_29.qasm: 0.0348759999999988s
# Time spent compiling so far: 0.530545
# Compilation time for circuit benchmarking/ibmq/miller_11.qasm: 0.04314800000000041s
# Time spent compiling so far: 0.5736930000000005
# Compilation time for circuit benchmarking/ibmq/alu-v3_34.qasm: 0.04771200000000064s
# Time spent compiling so far: 0.6214050000000011
# Compilation time for circuit benchmarking/ibmq/decod24-v2_43.qasm: 0.04659200000000041s
# Time spent compiling so far: 0.6679970000000015
# Compilation time for circuit benchmarking/ibmq/decod24-v0_38.qasm: 0.04116700000000151s
# Time spent compiling so far: 0.709164000000003
# Compilation time for circuit benchmarking/ibmq/mod5d2_64.qasm: 0.05070599999999992s
# Time spent compiling so far: 0.7598700000000029
# Compilation time for circuit benchmarking/ibmq/4gt13_92.qasm: 0.05255899999999869s
# Time spent compiling so far: 0.8124290000000016
# Compilation time for circuit benchmarking/ibmq/4gt13-v1_93.qasm: 0.055920000000000414s
# Time spent compiling so far: 0.868349000000002
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_18.qasm: 0.060874000000000095s
# Time spent compiling so far: 0.9292230000000021
# Compilation time for circuit benchmarking/ibmq/decod24-bdd_294.qasm: 0.0688089999999999s
# Time spent compiling so far: 0.998032000000002
# Compilation time for circuit benchmarking/ibmq/one-two-three-v2_100.qasm: 0.06764300000000034s
# Time spent compiling so far: 1.0656750000000024
# Compilation time for circuit benchmarking/ibmq/one-two-three-v3_101.qasm: 0.06322399999999995s
# Time spent compiling so far: 1.1288990000000023
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_23.qasm: 0.07023900000000083s
# Time spent compiling so far: 1.1991380000000031
# Compilation time for circuit benchmarking/ibmq/4mod5-bdd_287.qasm: 0.08391199999999976s
# Time spent compiling so far: 1.283050000000003
# Compilation time for circuit benchmarking/ibmq/rd32_270.qasm: 0.08249499999999976s
# Time spent compiling so far: 1.3655450000000027
# Compilation time for circuit benchmarking/ibmq/4gt5_75.qasm: 0.07955300000000065s
# Time spent compiling so far: 1.4450980000000033
# Compilation time for circuit benchmarking/ibmq/alu-bdd_288.qasm: 0.0908490000000004s
# Time spent compiling so far: 1.5359470000000037
# Compilation time for circuit benchmarking/ibmq/alu-v0_26.qasm: 0.07172599999999996s
# Time spent compiling so far: 1.6076730000000037
# Compilation time for circuit benchmarking/ibmq/decod24-v1_41.qasm: 0.07979599999999998s
# Time spent compiling so far: 1.6874690000000037
# Compilation time for circuit benchmarking/ibmq/rd53_138.qasm: 0.13728300000000004s
# Time spent compiling so far: 1.8247520000000037
# Compilation time for circuit benchmarking/ibmq/4gt5_76.qasm: 0.08127599999999902s
# Time spent compiling so far: 1.9060280000000027
# Compilation time for circuit benchmarking/ibmq/4gt13_91.qasm: 0.09426500000000004s
# Time spent compiling so far: 2.0002930000000028
# Compilation time for circuit benchmarking/ibmq/cnt3-5_179.qasm: 0.2902060000000013s
# Time spent compiling so far: 2.290499000000004
# Compilation time for circuit benchmarking/ibmq/qft_10.qasm: 0.3229430000000004s
# Time spent compiling so far: 2.6134420000000045
# Compilation time for circuit benchmarking/ibmq/4gt13_90.qasm: 0.10779300000000092s
# Time spent compiling so far: 2.7212350000000054
# Compilation time for circuit benchmarking/ibmq/alu-v4_36.qasm: 0.14896000000000065s
# Time spent compiling so far: 2.870195000000006
# Compilation time for circuit benchmarking/ibmq/mini_alu_305.qasm: 0.2920049999999996s
# Time spent compiling so far: 3.1622000000000057
# Compilation time for circuit benchmarking/ibmq/ising_model_10.qasm: 0.6689419999999995s
# Time spent compiling so far: 3.831142000000005
# Compilation time for circuit benchmarking/ibmq/ising_model_16.qasm: 1.2091959999999986s
# Time spent compiling so far: 5.040338000000004
# Compilation time for circuit benchmarking/ibmq/ising_model_13.qasm: 0.8298299999999976s
# Time spent compiling so far: 5.870168000000001
# Compilation time for circuit benchmarking/ibmq/4gt5_77.qasm: 0.13975899999999797s
# Time spent compiling so far: 6.009926999999999
# Compilation time for circuit benchmarking/ibmq/sys6-v0_111.qasm: 0.2691379999999981s
# Time spent compiling so far: 6.2790649999999975
# Compilation time for circuit benchmarking/ibmq/one-two-three-v1_99.qasm: 0.137871999999998s
# Time spent compiling so far: 6.4169369999999955
# Compilation time for circuit benchmarking/ibmq/one-two-three-v0_98.qasm: 0.14675300000000036s
# Time spent compiling so far: 6.563689999999996
# Compilation time for circuit benchmarking/ibmq/decod24-v3_45.qasm: 0.1615499999999983s
# Time spent compiling so far: 6.725239999999994
# Compilation time for circuit benchmarking/ibmq/4gt10-v1_81.qasm: 0.16231099999999898s
# Time spent compiling so far: 6.887550999999993
# Compilation time for circuit benchmarking/ibmq/aj-e11_165.qasm: 0.16981600000000086s
# Time spent compiling so far: 7.057366999999994
# Compilation time for circuit benchmarking/ibmq/4mod7-v0_94.qasm: 0.1652889999999978s
# Time spent compiling so far: 7.222655999999992
# Compilation time for circuit benchmarking/ibmq/alu-v2_32.qasm: 0.15397899999999964s
# Time spent compiling so far: 7.376634999999991
# Compilation time for circuit benchmarking/ibmq/rd73_140.qasm: 0.326588000000001s
# Time spent compiling so far: 7.703222999999992
# Compilation time for circuit benchmarking/ibmq/4mod7-v1_96.qasm: 0.16715599999999853s
# Time spent compiling so far: 7.870378999999991
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_80.qasm: 0.19897399999999976s
# Time spent compiling so far: 8.06935299999999
# Compilation time for circuit benchmarking/ibmq/mod10_176.qasm: 0.1703019999999995s
# Time spent compiling so far: 8.23965499999999
# Compilation time for circuit benchmarking/ibmq/0410184_169.qasm: 0.323677s
# Time spent compiling so far: 8.56333199999999
# Compilation time for circuit benchmarking/ibmq/qft_16.qasm: 0.8272300000000001s
# Time spent compiling so far: 9.39056199999999
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_88.qasm: 0.20004699999999787s
# Time spent compiling so far: 9.590608999999988
# Compilation time for circuit benchmarking/ibmq/rd84_142.qasm: 0.5740509999999972s
# Time spent compiling so far: 10.164659999999985
# Compilation time for circuit benchmarking/ibmq/rd53_311.qasm: 0.4584500000000027s
# Time spent compiling so far: 10.623109999999988
# Compilation time for circuit benchmarking/ibmq/4_49_16.qasm: 0.2564050000000009s
# Time spent compiling so far: 10.879514999999989
# Compilation time for circuit benchmarking/ibmq/sym9_146.qasm: 0.4764809999999997s
# Time spent compiling so far: 11.355995999999989
# Compilation time for circuit benchmarking/ibmq/4gt12-v1_89.qasm: 0.23908899999999988s
# Time spent compiling so far: 11.595084999999989
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_87.qasm: 0.2562649999999991s
# Time spent compiling so far: 11.851349999999988
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_79.qasm: 0.25176899999999947s
# Time spent compiling so far: 12.103118999999987
# Compilation time for circuit benchmarking/ibmq/hwb4_49.qasm: 0.21445099999999684s
# Time spent compiling so far: 12.317569999999984
# Compilation time for circuit benchmarking/ibmq/sym6_316.qasm: 0.4608920000000012s
# Time spent compiling so far: 12.778461999999985
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_86.qasm: 0.2541159999999998s
# Time spent compiling so far: 13.032577999999985
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_72.qasm: 0.2647519999999979s
# Time spent compiling so far: 13.297329999999983
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_78.qasm: 0.27057299999999884s
# Time spent compiling so far: 13.567902999999982
# Compilation time for circuit benchmarking/ibmq/mod10_171.qasm: 0.22629500000000036s
# Time spent compiling so far: 13.794197999999982
# Compilation time for circuit benchmarking/ibmq/4gt4-v1_74.qasm: 0.311475999999999s
# Time spent compiling so far: 14.105673999999981
# Compilation time for circuit benchmarking/ibmq/rd53_135.qasm: 0.3540460000000003s
# Time spent compiling so far: 14.459719999999981
# Compilation time for circuit benchmarking/ibmq/mini-alu_167.qasm: 0.2771159999999995s
# Time spent compiling so far: 14.73683599999998
# Compilation time for circuit benchmarking/ibmq/one-two-three-v0_97.qasm: 0.2893420000000013s
# Time spent compiling so far: 15.026177999999982
# Compilation time for circuit benchmarking/ibmq/ham7_104.qasm: 0.3568479999999994s
# Time spent compiling so far: 15.383025999999981
# Compilation time for circuit benchmarking/ibmq/decod24-enable_126.qasm: 0.38577699999999737s
# Time spent compiling so far: 15.768802999999979
# Compilation time for circuit benchmarking/ibmq/mod8-10_178.qasm: 0.4197650000000053s
# Time spent compiling so far: 16.188567999999982
# Compilation time for circuit benchmarking/ibmq/cnt3-5_180.qasm: 0.6787879999999973s
# Time spent compiling so far: 16.86735599999998
# Compilation time for circuit benchmarking/ibmq/ex3_229.qasm: 0.43368600000000157s
# Time spent compiling so far: 17.30104199999998
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_73.qasm: 0.40907400000000393s
# Time spent compiling so far: 17.710115999999985
# Compilation time for circuit benchmarking/ibmq/mod8-10_177.qasm: 0.49698399999999765s
# Time spent compiling so far: 18.207099999999983
# Compilation time for circuit benchmarking/ibmq/C17_204.qasm: 0.5234019999999973s
# Time spent compiling so far: 18.73050199999998
# Compilation time for circuit benchmarking/ibmq/alu-v2_31.qasm: 0.4226379999999992s
# Time spent compiling so far: 19.15313999999998
# Compilation time for circuit benchmarking/ibmq/rd53_131.qasm: 0.5377189999999956s
# Time spent compiling so far: 19.690858999999975
# Compilation time for circuit benchmarking/ibmq/alu-v2_30.qasm: 0.5641069999999999s
# Time spent compiling so far: 20.254965999999975
# Compilation time for circuit benchmarking/ibmq/mod5adder_127.qasm: 0.6230819999999966s
# Time spent compiling so far: 20.87804799999997
# Compilation time for circuit benchmarking/ibmq/rd53_133.qasm: 0.7587010000000021s
# Time spent compiling so far: 21.636748999999973
# Compilation time for circuit benchmarking/ibmq/cm82a_208.qasm: 0.8314120000000003s
# Time spent compiling so far: 22.468160999999974
# Compilation time for circuit benchmarking/ibmq/majority_239.qasm: 0.7012590000000003s
# Time spent compiling so far: 23.169419999999974
# Compilation time for circuit benchmarking/ibmq/ex2_227.qasm: 0.8390540000000044s
# Time spent compiling so far: 24.00847399999998
# Compilation time for circuit benchmarking/ibmq/sf_276.qasm: 0.8613420000000005s
# Time spent compiling so far: 24.86981599999998
# Compilation time for circuit benchmarking/ibmq/sf_274.qasm: 0.889561999999998s
# Time spent compiling so far: 25.759377999999977
# Compilation time for circuit benchmarking/ibmq/con1_216.qasm: 1.3333489999999983s
# Time spent compiling so far: 27.092726999999975
# Compilation time for circuit benchmarking/ibmq/wim_266.qasm: 1.3323309999999964s
# Time spent compiling so far: 28.42505799999997
# Compilation time for circuit benchmarking/ibmq/rd53_130.qasm: 1.205401000000002s
# Time spent compiling so far: 29.630458999999973
# Compilation time for circuit benchmarking/ibmq/f2_232.qasm: 1.6179269999999946s
# Time spent compiling so far: 31.248385999999968
# Compilation time for circuit benchmarking/ibmq/cm152a_212.qasm: 2.5537959999999984s
# Time spent compiling so far: 33.802181999999966
# Compilation time for circuit benchmarking/ibmq/rd53_251.qasm: 2.057509000000003s
# Time spent compiling so far: 35.85969099999997
# Compilation time for circuit benchmarking/ibmq/hwb5_53.qasm: 1.7147840000000016s
# Time spent compiling so far: 37.57447499999997
# Compilation time for circuit benchmarking/ibmq/cm42a_207.qasm: 2.645614000000002s
# Time spent compiling so far: 40.22008899999997
# Compilation time for circuit benchmarking/ibmq/pm1_249.qasm: 2.617726999999995s
# Time spent compiling so far: 42.83781599999997
# Compilation time for circuit benchmarking/ibmq/dc1_220.qasm: 2.810992000000013s
# Time spent compiling so far: 45.64880799999998
# Compilation time for circuit benchmarking/ibmq/squar5_261.qasm: 3.243397999999999s
# Time spent compiling so far: 48.89220599999998
# Compilation time for circuit benchmarking/ibmq/z4_268.qasm: 5.057941999999997s
# Time spent compiling so far: 53.95014799999998
# Compilation time for circuit benchmarking/ibmq/sqrt8_260.qasm: 5.122843000000003s
# Time spent compiling so far: 59.07299099999998
# Compilation time for circuit benchmarking/ibmq/radd_250.qasm: 5.995917999999989s
# Time spent compiling so far: 65.06890899999996
# Compilation time for circuit benchmarking/ibmq/adr4_197.qasm: 6.295682999999997s
# Time spent compiling so far: 71.36459199999996
# Compilation time for circuit benchmarking/ibmq/sym6_145.qasm: 4.685117000000005s
# Time spent compiling so far: 76.04970899999996
# Compilation time for circuit benchmarking/ibmq/misex1_241.qasm: 7.795224000000005s
# Time spent compiling so far: 83.84493299999997
# Compilation time for circuit benchmarking/ibmq/rd73_252.qasm: 7.921928999999992s
# Time spent compiling so far: 91.76686199999996
# Compilation time for circuit benchmarking/ibmq/cycle10_2_110.qasm: 10.821911999999998s
# Time spent compiling so far: 102.58877399999996
# Compilation time for circuit benchmarking/ibmq/hwb6_56.qasm: 9.641422000000006s
# Time spent compiling so far: 112.23019599999996
# Compilation time for circuit benchmarking/ibmq/square_root_7.qasm: 15.391211999999996s
# Time spent compiling so far: 127.62140799999996
# Compilation time for circuit benchmarking/ibmq/ham15_107.qasm: 15.627421999999996s
# Time spent compiling so far: 143.24882999999994
# Compilation time for circuit benchmarking/ibmq/dc2_222.qasm: 17.383571999999987s
# Time spent compiling so far: 160.63240199999993
# Compilation time for circuit benchmarking/ibmq/sqn_258.qasm: 16.52294600000002s
# Time spent compiling so far: 177.15534799999995
# Compilation time for circuit benchmarking/ibmq/inc_237.qasm: 18.12044499999999s
# Time spent compiling so far: 195.27579299999994
# Compilation time for circuit benchmarking/ibmq/cm85a_209.qasm: 21.677613000000008s
# Time spent compiling so far: 216.95340599999994
# Compilation time for circuit benchmarking/ibmq/rd84_253.qasm: 22.859430999999972s
# Time spent compiling so far: 239.81283699999992
# Compilation time for circuit benchmarking/ibmq/co14_215.qasm: 37.30490200000003s
# Time spent compiling so far: 277.1177389999999
# Compilation time for circuit benchmarking/ibmq/root_255.qasm: 31.208718999999974s
# Time spent compiling so far: 308.3264579999999
# Compilation time for circuit benchmarking/ibmq/mlp4_245.qasm: 36.48735399999998s
# Time spent compiling so far: 344.81381199999987
# Compilation time for circuit benchmarking/ibmq/urf2_277.qasm: 31.95310900000004s
# Time spent compiling so far: 376.7669209999999
# Compilation time for circuit benchmarking/ibmq/sym9_148.qasm: 33.49015700000001s
# Time spent compiling so far: 410.2570779999999
# Compilation time for circuit benchmarking/ibmq/life_238.qasm: 36.476549999999975s
# Time spent compiling so far: 446.7336279999999
# Compilation time for circuit benchmarking/ibmq/hwb7_59.qasm: 36.82935300000008s
# Time spent compiling so far: 483.562981
# Compilation time for circuit benchmarking/ibmq/max46_240.qasm: 43.73224800000003s
# Time spent compiling so far: 527.2952290000001
# Compilation time for circuit benchmarking/ibmq/clip_206.qasm: 68.39072099999998s
# Time spent compiling so far: 595.68595
# Compilation time for circuit benchmarking/ibmq/9symml_195.qasm: 58.05880300000001s
# Time spent compiling so far: 653.7447530000001
# Compilation time for circuit benchmarking/ibmq/sym9_193.qasm: 61.888829999999984s
# Time spent compiling so far: 715.633583
# Compilation time for circuit benchmarking/ibmq/sao2_257.qasm: 78.200423s
# Time spent compiling so far: 793.834006
# Compilation time for circuit benchmarking/ibmq/dist_223.qasm: 66.15623299999993s
# Time spent compiling so far: 859.990239
# Compilation time for circuit benchmarking/ibmq/urf5_280.qasm: 81.94408599999997s
# Time spent compiling so far: 941.934325
# Compilation time for circuit benchmarking/ibmq/urf1_278.qasm: 93.68620699999997s
# Time spent compiling so far: 1035.620532
# Compilation time for circuit benchmarking/ibmq/sym10_262.qasm: 112.48571800000013s
# Time spent compiling so far: 1148.10625
