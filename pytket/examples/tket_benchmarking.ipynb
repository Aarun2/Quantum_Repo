# %% [markdown]
# # tket benchmarking example

# %% [markdown]
# Warning: This notebook is now deprecated for versions from 0.2.0 onwards, and is not going to be updated in ongoing releases.
#
# The aim of this example is to show how to run the IBM benchmarking circuits through tket. You will need both `pytket` and `pytket_qiskit` installed from pip before running this turoial. You will also need `pandas` to capture the data.
#
# The benchmarking circuits originated from https://github.com/iic-jku/ibm_qx_mapping/tree/master/examples, but there is a copy in pytket in the "benchmarking" folder. The initial circuits are written in QASM, meaning that they must be converted to tket's internal representation via Qiskit. Using this script we will compile these circuits through tket and then print a table to terminal containing analysis of the circuits post-compilation.
#
# First, begin by importing qiskit and pytket.

# %%
import qiskit
import pytket

# %% [markdown]
# We need access to Qiskit's `QuantumCircuit` and the `circuit_to_dag` converter, which will allow us to take the original QASM and retrieve a Qiskit DAGCircuit. There is then a pytket method `dagcircuit_to_tk` to convert this DAGCircuit to tket's internal representation. We also need the pytket method `coupling_to_arc` to convert IBM's architectures to the tket `Architecture` class for the use of routing.

# %%
from qiskit import QuantumCircuit

from pytket.extensions.qiskit import qiskit_to_tk
from pytket.passes import PlacementPass, RoutingPass
from pytket.predicates import CompilationUnit
from pytket.routing import GraphPlacement

# %% [markdown]
# We need all of the required pytket equipment to allow us to perform clean-up transform passes, to route and to analyse the circuits. Lastly, we require the `pandas` module to hold our data, and
# `time` to benchmark compilation time per circuit.

# %% [markdown]
# The architectures used to benchmark for our routing paper were the IBMqx5 and IBMTokyo architectures. The architectures qx5 and Tokyo respectively are shown below (although the diagrams do not show the directedness of the coupling maps). These diagrams are from https://www.research.ibm.com/ibm-q/technology/devices/#ibmqx5. We will now define the coupling map representing both architectures. These will later be converted to directed graphs to be used by tket.
# ![alt text](IBMqx5Arc.png "Title")
# ![alt text](IBMTokyoArc.png "Title2")

# %%
from pytket.routing import Architecture, route
from pytket.transform import Transform
from pytket import OpType
from pytket import circuit
from pytket.routing import Placement
import pandas
import time

# %%
ibm_devices = {
    "ibmqx5": {"edges": [(1, 0), (1, 2), (2, 3), (3, 4), 
    (3, 14), (5, 4), (6, 5), (6, 7), (6, 11), (7, 10), 
    (8, 7), (9, 8), (9, 10), (11, 10), (12, 5), (12, 11), 
    (12, 13), (13, 4), (13, 14), (15, 0), (15, 2), (15, 14)],
    "nodes": 16},
    "ibmq_20_tokyo": {"edges": [(0, 1), (0, 5), (1, 2), (1, 6), (1, 7), (2, 3), (2, 6),
    (2, 7), (3, 4), (3, 8), (3, 9), (4, 8), (4, 9), (5, 6), (5, 10), (5, 11), (6, 7),
    (6, 10), (6, 11), (7, 8), (7, 12), (7, 13), (8, 9), (8, 12), (8, 13), (9, 14), (10, 11),
    (10, 15), (11, 12), (11, 16), (11, 17), (12, 13), (12, 16), (12, 17), (13, 14), (13, 18),
    (13, 19), (14, 18), (14, 19), (15, 16), (16, 17), (17, 18), (18, 19)], "nodes": 20},
    "Rochester" : {"edges": [(0, 1), (0, 5), (1, 2), (2, 3), (3, 4), (4, 6), (5, 9),
    (6, 13), (7, 8), (16, 7), (16, 19), (8, 9),  (9, 10), (10, 11), (11, 12), (12, 13), (13, 14), (14, 15), (11, 17),
    (15, 18), (18, 27), (19, 20), (20, 21), (21, 22), (22, 23), (17, 23), (23, 24), (24, 25), (25, 26), (26, 27),
    (21, 28), (28, 32), (25, 29), (29, 36), (30, 31), (31, 32), (32, 33), (33, 34), (34, 35), (35, 36), (36, 37), 
    (37, 38), (30, 39), (39, 42), (34, 40), (38, 41), (40, 46), (41, 50), (42, 43), (43, 44), (44, 45), 
    (45, 46), (46, 47), (47, 48), (48, 49), (49, 50), (48, 52), (44, 51)], "nodes": 53}
}

# %% [markdown]
# We shall now choose the device and create a directed graph for tket's routing to use.

# %%
device_name = 'Rochester' ###Note: can also be ran using the Tokyo machine architecture
                                       ###      or with a user-defined coupling map
coupling_map = ibm_devices[device_name]["edges"]
directed_arc = Architecture(coupling_map)
device = pytket.device.Device({}, {}, directed_arc)

# %% [markdown]
# We now define a method which takes in (1) a QASM file and (2) a directed graph architecture; it returns analysis of the circuit after our transform passes and routing procedure have been completed. It will also print out to terminal the time taken for all the transformations and routing to finish. Changing which optimisations are run in this method will trade off quality of the ouputs for time taken. For example, removing all optimisation passes and just running the routing procedure will give the fastest run time but may leave some redundant gates in the final circuit.

# %%
def getStats(filename, directed_arc):
    qc = QuantumCircuit.from_qasm_file(filename)
    tkcirc = qiskit_to_tk(qc)
    #cu = CompilationUnit(tkcirc)
    start_time = time.process_time()
    PlacementPass(GraphPlacement(device)).apply(tkcirc)
    RoutingPass(device).apply(tkcirc)
    #while (~DirectednessPredicate({}).verify(tkcirc)):
      #  RebaseTket().apply(tkcirc)
    # print(cu.initial_map)
    # print(cu.final_map)
    
    time_elapsed = time.process_time() - start_time
    
    print("Compilation time for circuit " + str(filename) + ": " + str(time_elapsed) + "s")
    
    #render_circuit_jupyter(tkcirc)
    if tkcirc.n_gates==0:
        return [0,0,0,0,0]
    ###Returns: [number of vertices, circuit depth, nubmer of CX gates, number of parallel slices of CX gates]
    return [tkcirc.n_gates, tkcirc.depth(), tkcirc.n_gates_of_type(OpType.CX), 
            tkcirc.depth_by_type(OpType.CX), time_elapsed]
    ###Note: the raw number of vertices in the circuits and the raw depth 
    ###      need to have the i/o vertices removed for fair comparisons

# %% [markdown]
# Lastly, we generate the table of input QASM filenames from a csv file using `pandas` and run the circuits through our compiler. The results are printed to terminal by default.

# %%
test_table = pandas.read_csv("benchmarking/IBMQConfig.csv",index_col=0)
test_table = test_table.sort_values(by='Depth in')

stat_table = pandas.DataFrame({})
total_time = 0

for i, (index, row) in enumerate(test_table.iterrows()):
    filename = row['Filename']
    new_stats = getStats(filename, directed_arc)
    total_time += new_stats[4] ###
    print("Time spent compiling so far: " + str(total_time))
    new_table_row = pandas.DataFrame.from_dict({index : new_stats}, 
    orient='index', columns=['Size out', 'Depth out', 'CX count out', 'CX depth out','Runtime'])
    stat_table = stat_table.append(new_table_row)

#stat_table.to_csv("BenchmarkTket.csv") ###Note: uncomment this line to print table to csv.
with pandas.option_context('display.max_rows', None):
    print(stat_table)
# Out:
# Compilation time for circuit benchmarking/ibmq/xor5_254.qasm: 0.01323099999990518s
# Time spent compiling so far: 0.01323099999990518
# Compilation time for circuit benchmarking/ibmq/graycode6_47.qasm: 0.016795000000001892s
# Time spent compiling so far: 0.03002599999990707
# Compilation time for circuit benchmarking/ibmq/ex1_226.qasm: 0.011643000000276515s
# Time spent compiling so far: 0.04166900000018359
# Compilation time for circuit benchmarking/ibmq/4gt11_84.qasm: 0.012564000000111264s
# Time spent compiling so far: 0.05423300000029485
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_20.qasm: 0.010238000000299508s
# Time spent compiling so far: 0.06447100000059436
# Compilation time for circuit benchmarking/ibmq/ex-1_166.qasm: 0.009661000000505737s
# Time spent compiling so far: 0.0741320000011001
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_22.qasm: 0.012208999999984371s
# Time spent compiling so far: 0.08634100000108447
# Compilation time for circuit benchmarking/ibmq/mod5d1_63.qasm: 0.011402999999972963s
# Time spent compiling so far: 0.09774400000105743
# Compilation time for circuit benchmarking/ibmq/ham3_102.qasm: 0.010775999999623309s
# Time spent compiling so far: 0.10852000000068074
# Compilation time for circuit benchmarking/ibmq/4gt11_83.qasm: 0.011723999999958323s
# Time spent compiling so far: 0.12024400000063906
# Compilation time for circuit benchmarking/ibmq/4gt11_82.qasm: 0.016150000000379805s
# Time spent compiling so far: 0.13639400000101887
# Compilation time for circuit benchmarking/ibmq/rd32-v0_66.qasm: 0.011104999999588472s
# Time spent compiling so far: 0.14749900000060734
# Compilation time for circuit benchmarking/ibmq/alu-v0_27.qasm: 0.018651999999747204s
# Time spent compiling so far: 0.16615100000035454
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_24.qasm: 0.09253800000033152s
# Time spent compiling so far: 0.25868900000068606
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_19.qasm: 0.01890300000059142s
# Time spent compiling so far: 0.2775920000012775
# Compilation time for circuit benchmarking/ibmq/mod5mils_65.qasm: 0.02128699999957462s
# Time spent compiling so far: 0.2988790000008521
# Compilation time for circuit benchmarking/ibmq/rd32-v1_68.qasm: 0.012287000000014814s
# Time spent compiling so far: 0.3111660000008669
# Compilation time for circuit benchmarking/ibmq/alu-v1_28.qasm: 0.01303799999959665s
# Time spent compiling so far: 0.32420400000046357
# Compilation time for circuit benchmarking/ibmq/alu-v2_33.qasm: 0.012709999999970023s
# Time spent compiling so far: 0.3369140000004336
# Compilation time for circuit benchmarking/ibmq/alu-v4_37.qasm: 0.012817000000268308s
# Time spent compiling so far: 0.3497310000007019
# Compilation time for circuit benchmarking/ibmq/alu-v3_35.qasm: 0.012430000000222208s
# Time spent compiling so far: 0.3621610000009241
# Compilation time for circuit benchmarking/ibmq/3_17_13.qasm: 0.011594999999942956s
# Time spent compiling so far: 0.37375600000086706
# Compilation time for circuit benchmarking/ibmq/alu-v1_29.qasm: 0.01342400000021371s
# Time spent compiling so far: 0.38718000000108077
# Compilation time for circuit benchmarking/ibmq/miller_11.qasm: 0.013015999999879568s
# Time spent compiling so far: 0.40019600000096034
# Compilation time for circuit benchmarking/ibmq/alu-v3_34.qasm: 0.019252999999935128s
# Time spent compiling so far: 0.41944900000089547
# Compilation time for circuit benchmarking/ibmq/decod24-v2_43.qasm: 0.013588000000254397s
# Time spent compiling so far: 0.43303700000114986
# Compilation time for circuit benchmarking/ibmq/decod24-v0_38.qasm: 0.013902000000143744s
# Time spent compiling so far: 0.4469390000012936
# Compilation time for circuit benchmarking/ibmq/mod5d2_64.qasm: 0.01786000000038257s
# Time spent compiling so far: 0.4647990000016762
# Compilation time for circuit benchmarking/ibmq/4gt13_92.qasm: 0.08449500000006083s
# Time spent compiling so far: 0.549294000001737
# Compilation time for circuit benchmarking/ibmq/4gt13-v1_93.qasm: 0.08775000000014188s
# Time spent compiling so far: 0.6370440000018789
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_18.qasm: 0.02129899999999907s
# Time spent compiling so far: 0.658343000001878
# Compilation time for circuit benchmarking/ibmq/decod24-bdd_294.qasm: 0.023294000000078086s
# Time spent compiling so far: 0.681637000001956
# Compilation time for circuit benchmarking/ibmq/one-two-three-v2_100.qasm: 0.01636400000006688s
# Time spent compiling so far: 0.6980010000020229
# Compilation time for circuit benchmarking/ibmq/one-two-three-v3_101.qasm: 0.015658000000257744s
# Time spent compiling so far: 0.7136590000022807
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_23.qasm: 0.022035999999843625s
# Time spent compiling so far: 0.7356950000021243
# Compilation time for circuit benchmarking/ibmq/4mod5-bdd_287.qasm: 0.019457999999758613s
# Time spent compiling so far: 0.7551530000018829
# Compilation time for circuit benchmarking/ibmq/rd32_270.qasm: 0.02299200000015844s
# Time spent compiling so far: 0.7781450000020413
# Compilation time for circuit benchmarking/ibmq/4gt5_75.qasm: 0.02055400000017471s
# Time spent compiling so far: 0.798699000002216
# Compilation time for circuit benchmarking/ibmq/alu-bdd_288.qasm: 0.08646300000009433s
# Time spent compiling so far: 0.8851620000023104
# Compilation time for circuit benchmarking/ibmq/alu-v0_26.qasm: 0.03068799999937255s
# Time spent compiling so far: 0.9158500000016829
# Compilation time for circuit benchmarking/ibmq/decod24-v1_41.qasm: 0.08822800000007192s
# Time spent compiling so far: 1.0040780000017548
# Compilation time for circuit benchmarking/ibmq/rd53_138.qasm: 0.040705000000343716s
# Time spent compiling so far: 1.0447830000020986
# Compilation time for circuit benchmarking/ibmq/4gt5_76.qasm: 0.02987600000005841s
# Time spent compiling so far: 1.074659000002157
# Compilation time for circuit benchmarking/ibmq/4gt13_91.qasm: 0.023254000000179076s
# Time spent compiling so far: 1.097913000002336
# Compilation time for circuit benchmarking/ibmq/cnt3-5_179.qasm: 0.17557099999976344s
# Time spent compiling so far: 1.2734840000020995
# Compilation time for circuit benchmarking/ibmq/qft_10.qasm: 0.048620000000028085s
# Time spent compiling so far: 1.3221040000021276
# Compilation time for circuit benchmarking/ibmq/4gt13_90.qasm: 0.030032000000574044s
# Time spent compiling so far: 1.3521360000027016
# Compilation time for circuit benchmarking/ibmq/alu-v4_36.qasm: 0.11852699999963079s
# Time spent compiling so far: 1.4706630000023324
# Compilation time for circuit benchmarking/ibmq/mini_alu_305.qasm: 0.05543699999998353s
# Time spent compiling so far: 1.526100000002316
# Compilation time for circuit benchmarking/ibmq/ising_model_10.qasm: 0.022829999999430584s
# Time spent compiling so far: 1.5489300000017465
# Compilation time for circuit benchmarking/ibmq/ising_model_16.qasm: 0.048553999999967346s
# Time spent compiling so far: 1.5974840000017139
# Compilation time for circuit benchmarking/ibmq/ising_model_13.qasm: 0.036251000000447675s
# Time spent compiling so far: 1.6337350000021615
# Compilation time for circuit benchmarking/ibmq/4gt5_77.qasm: 0.02514100000007602s
# Time spent compiling so far: 1.6588760000022376
# Compilation time for circuit benchmarking/ibmq/sys6-v0_111.qasm: 0.05687900000020818s
# Time spent compiling so far: 1.7157550000024457
# Compilation time for circuit benchmarking/ibmq/one-two-three-v1_99.qasm: 0.08920100000023012s
# Time spent compiling so far: 1.8049560000026759
# Compilation time for circuit benchmarking/ibmq/one-two-three-v0_98.qasm: 0.08800300000029893s
# Time spent compiling so far: 1.8929590000029748
# Compilation time for circuit benchmarking/ibmq/decod24-v3_45.qasm: 0.09923700000035751s
# Time spent compiling so far: 1.9921960000033323
# Compilation time for circuit benchmarking/ibmq/4gt10-v1_81.qasm: 0.08727399999997942s
# Time spent compiling so far: 2.0794700000033117
# Compilation time for circuit benchmarking/ibmq/aj-e11_165.qasm: 0.036837000000105036s
# Time spent compiling so far: 2.1163070000034168
# Compilation time for circuit benchmarking/ibmq/4mod7-v0_94.qasm: 0.09215500000027532s
# Time spent compiling so far: 2.208462000003692
# Compilation time for circuit benchmarking/ibmq/alu-v2_32.qasm: 0.04147000000011758s
# Time spent compiling so far: 2.2499320000038097
# Compilation time for circuit benchmarking/ibmq/rd73_140.qasm: 0.07112600000027669s
# Time spent compiling so far: 2.3210580000040864
# Compilation time for circuit benchmarking/ibmq/4mod7-v1_96.qasm: 0.04634100000021135s
# Time spent compiling so far: 2.3673990000042977
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_80.qasm: 0.049165999999786436s
# Time spent compiling so far: 2.416565000004084
# Compilation time for circuit benchmarking/ibmq/mod10_176.qasm: 0.09721599999966202s
# Time spent compiling so far: 2.513781000003746
# Compilation time for circuit benchmarking/ibmq/0410184_169.qasm: 0.23960299999998824s
# Time spent compiling so far: 2.7533840000037344
# Compilation time for circuit benchmarking/ibmq/qft_16.qasm: 0.1869369999999435s
# Time spent compiling so far: 2.940321000003678
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_88.qasm: 0.05250400000068112s
# Time spent compiling so far: 2.992825000004359
# Compilation time for circuit benchmarking/ibmq/rd84_142.qasm: 0.11612000000013722s
# Time spent compiling so far: 3.1089450000044963
# Compilation time for circuit benchmarking/ibmq/rd53_311.qasm: 0.10586499999999432s
# Time spent compiling so far: 3.2148100000044906
# Compilation time for circuit benchmarking/ibmq/4_49_16.qasm: 0.1061440000003131s
# Time spent compiling so far: 3.3209540000048037
# Compilation time for circuit benchmarking/ibmq/sym9_146.qasm: 0.09938400000010006s
# Time spent compiling so far: 3.4203380000049037
# Compilation time for circuit benchmarking/ibmq/4gt12-v1_89.qasm: 0.04960399999981746s
# Time spent compiling so far: 3.469942000004721
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_87.qasm: 0.06710499999962849s
# Time spent compiling so far: 3.5370470000043497
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_79.qasm: 0.056172999999944295s
# Time spent compiling so far: 3.593220000004294
# Compilation time for circuit benchmarking/ibmq/hwb4_49.qasm: 0.05447999999978492s
# Time spent compiling so far: 3.647700000004079
# Compilation time for circuit benchmarking/ibmq/sym6_316.qasm: 0.11277300000028845s
# Time spent compiling so far: 3.7604730000043673
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_86.qasm: 0.06321399999978894s
# Time spent compiling so far: 3.8236870000041563
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_72.qasm: 0.07432799999969575s
# Time spent compiling so far: 3.898015000003852
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_78.qasm: 0.10939700000017183s
# Time spent compiling so far: 4.007412000004024
# Compilation time for circuit benchmarking/ibmq/mod10_171.qasm: 0.08245099999976446s
# Time spent compiling so far: 4.089863000003788
# Compilation time for circuit benchmarking/ibmq/4gt4-v1_74.qasm: 0.122110999999677s
# Time spent compiling so far: 4.211974000003465
# Compilation time for circuit benchmarking/ibmq/rd53_135.qasm: 0.13920499999994718s
# Time spent compiling so far: 4.3511790000034125
# Compilation time for circuit benchmarking/ibmq/mini-alu_167.qasm: 0.09396900000047026s
# Time spent compiling so far: 4.445148000003883
# Compilation time for circuit benchmarking/ibmq/one-two-three-v0_97.qasm: 0.19491000000016356s
# Time spent compiling so far: 4.640058000004046
# Compilation time for circuit benchmarking/ibmq/ham7_104.qasm: 0.23908700000038152s
# Time spent compiling so far: 4.879145000004428
# Compilation time for circuit benchmarking/ibmq/decod24-enable_126.qasm: 0.2260020000003351s
# Time spent compiling so far: 5.105147000004763
# Compilation time for circuit benchmarking/ibmq/mod8-10_178.qasm: 0.16052599999966333s
# Time spent compiling so far: 5.265673000004426
# Compilation time for circuit benchmarking/ibmq/cnt3-5_180.qasm: 0.26052500000014334s
# Time spent compiling so far: 5.52619800000457
# Compilation time for circuit benchmarking/ibmq/ex3_229.qasm: 0.2671229999996285s
# Time spent compiling so far: 5.793321000004198
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_73.qasm: 0.14608300000008967s
# Time spent compiling so far: 5.939404000004288
# Compilation time for circuit benchmarking/ibmq/mod8-10_177.qasm: 0.1399370000003728s
# Time spent compiling so far: 6.079341000004661
# Compilation time for circuit benchmarking/ibmq/C17_204.qasm: 0.13509799999928873s
# Time spent compiling so far: 6.214439000003949
# Compilation time for circuit benchmarking/ibmq/alu-v2_31.qasm: 0.07769899999993868s
# Time spent compiling so far: 6.292138000003888
# Compilation time for circuit benchmarking/ibmq/rd53_131.qasm: 0.17893099999992046s
# Time spent compiling so far: 6.4710690000038085
# Compilation time for circuit benchmarking/ibmq/alu-v2_30.qasm: 0.189733000000615s
# Time spent compiling so far: 6.6608020000044235
# Compilation time for circuit benchmarking/ibmq/mod5adder_127.qasm: 0.19851900000003297s
# Time spent compiling so far: 6.859321000004456
# Compilation time for circuit benchmarking/ibmq/rd53_133.qasm: 0.22403200000007928s
# Time spent compiling so far: 7.083353000004536
# Compilation time for circuit benchmarking/ibmq/cm82a_208.qasm: 0.2039429999999811s
# Time spent compiling so far: 7.287296000004517
# Compilation time for circuit benchmarking/ibmq/majority_239.qasm: 0.2228600000003098s
# Time spent compiling so far: 7.510156000004827
# Compilation time for circuit benchmarking/ibmq/ex2_227.qasm: 0.2676080000001093s
# Time spent compiling so far: 7.777764000004936
# Compilation time for circuit benchmarking/ibmq/sf_276.qasm: 0.2647109999998065s
# Time spent compiling so far: 8.042475000004742
# Compilation time for circuit benchmarking/ibmq/sf_274.qasm: 0.3558659999998781s
# Time spent compiling so far: 8.39834100000462
# Compilation time for circuit benchmarking/ibmq/con1_216.qasm: 0.5114729999995689s
# Time spent compiling so far: 8.90981400000419
# Compilation time for circuit benchmarking/ibmq/wim_266.qasm: 0.4415109999999913s
# Time spent compiling so far: 9.35132500000418
# Compilation time for circuit benchmarking/ibmq/rd53_130.qasm: 0.36939600000005157s
# Time spent compiling so far: 9.720721000004232
# Compilation time for circuit benchmarking/ibmq/f2_232.qasm: 0.4793490000001839s
# Time spent compiling so far: 10.200070000004416
# Compilation time for circuit benchmarking/ibmq/cm152a_212.qasm: 0.48752299999978277s
# Time spent compiling so far: 10.687593000004199
# Compilation time for circuit benchmarking/ibmq/rd53_251.qasm: 0.5066759999999704s
# Time spent compiling so far: 11.19426900000417
# Compilation time for circuit benchmarking/ibmq/hwb5_53.qasm: 0.375376999999844s
# Time spent compiling so far: 11.569646000004013
# Compilation time for circuit benchmarking/ibmq/cm42a_207.qasm: 0.7326440000001639s
# Time spent compiling so far: 12.302290000004177
# Compilation time for circuit benchmarking/ibmq/pm1_249.qasm: 0.7934839999998076s
# Time spent compiling so far: 13.095774000003985
# Compilation time for circuit benchmarking/ibmq/dc1_220.qasm: 0.7391480000001138s
# Time spent compiling so far: 13.834922000004099
# Compilation time for circuit benchmarking/ibmq/squar5_261.qasm: 0.8129329999997026s
# Time spent compiling so far: 14.647855000003801
# Compilation time for circuit benchmarking/ibmq/z4_268.qasm: 1.209266999999727s
# Time spent compiling so far: 15.857122000003528
# Compilation time for circuit benchmarking/ibmq/sqrt8_260.qasm: 1.2831860000001143s
# Time spent compiling so far: 17.140308000003643
# Compilation time for circuit benchmarking/ibmq/radd_250.qasm: 1.24827600000026s
# Time spent compiling so far: 18.388584000003902
# Compilation time for circuit benchmarking/ibmq/adr4_197.qasm: 1.4640890000000581s
# Time spent compiling so far: 19.85267300000396
# Compilation time for circuit benchmarking/ibmq/sym6_145.qasm: 1.1842289999995046s
# Time spent compiling so far: 21.036902000003465
# Compilation time for circuit benchmarking/ibmq/misex1_241.qasm: 1.9346810000001824s
# Time spent compiling so far: 22.971583000003648
# Compilation time for circuit benchmarking/ibmq/rd73_252.qasm: 2.0127189999998336s
# Time spent compiling so far: 24.98430200000348
# Compilation time for circuit benchmarking/ibmq/cycle10_2_110.qasm: 2.7120780000000195s
# Time spent compiling so far: 27.6963800000035
# Compilation time for circuit benchmarking/ibmq/hwb6_56.qasm: 1.9961739999998827s
# Time spent compiling so far: 29.692554000003383
# Compilation time for circuit benchmarking/ibmq/square_root_7.qasm: 3.257231000000047s
# Time spent compiling so far: 32.94978500000343
# Compilation time for circuit benchmarking/ibmq/ham15_107.qasm: 3.606044000000111s
# Time spent compiling so far: 36.55582900000354
# Compilation time for circuit benchmarking/ibmq/dc2_222.qasm: 4.312899000000016s
# Time spent compiling so far: 40.86872800000356
# Compilation time for circuit benchmarking/ibmq/sqn_258.qasm: 4.029433000000154s
# Time spent compiling so far: 44.89816100000371
# Compilation time for circuit benchmarking/ibmq/inc_237.qasm: 4.1471980000005715s
# Time spent compiling so far: 49.04535900000428
# Compilation time for circuit benchmarking/ibmq/cm85a_209.qasm: 5.130575000000135s
# Time spent compiling so far: 54.17593400000442
# Compilation time for circuit benchmarking/ibmq/rd84_253.qasm: 6.260479000000032s
# Time spent compiling so far: 60.43641300000445
# Compilation time for circuit benchmarking/ibmq/co14_215.qasm: 9.639894000000368s
# Time spent compiling so far: 70.07630700000482
# Compilation time for circuit benchmarking/ibmq/root_255.qasm: 7.735573999999815s
# Time spent compiling so far: 77.81188100000463
# Compilation time for circuit benchmarking/ibmq/mlp4_245.qasm: 9.223505999999816s
# Time spent compiling so far: 87.03538700000445
# Compilation time for circuit benchmarking/ibmq/urf2_277.qasm: 7.85569600000008s
# Time spent compiling so far: 94.89108300000453
# Compilation time for circuit benchmarking/ibmq/sym9_148.qasm: 7.467023999999583s
# Time spent compiling so far: 102.35810700000411
# Compilation time for circuit benchmarking/ibmq/life_238.qasm: 10.533899999999903s
# Time spent compiling so far: 112.89200700000401
# Compilation time for circuit benchmarking/ibmq/hwb7_59.qasm: 8.195958000000246s
# Time spent compiling so far: 121.08796500000426
# Compilation time for circuit benchmarking/ibmq/max46_240.qasm: 10.860957999999755s
# Time spent compiling so far: 131.94892300000402
# Compilation time for circuit benchmarking/ibmq/clip_206.qasm: 16.848403000000417s
# Time spent compiling so far: 148.79732600000443
# Compilation time for circuit benchmarking/ibmq/9symml_195.qasm: 14.81597499999998s
# Time spent compiling so far: 163.6133010000044
# Compilation time for circuit benchmarking/ibmq/sym9_193.qasm: 15.28943900000013s
# Time spent compiling so far: 178.90274000000454
# Compilation time for circuit benchmarking/ibmq/sao2_257.qasm: 17.534291999999823s
# Time spent compiling so far: 196.43703200000436
# Compilation time for circuit benchmarking/ibmq/dist_223.qasm: 16.792591999999786s
# Time spent compiling so far: 213.22962400000415
# Compilation time for circuit benchmarking/ibmq/urf5_280.qasm: 19.884625000000597s
# Time spent compiling so far: 233.11424900000475
# Compilation time for circuit benchmarking/ibmq/urf1_278.qasm: 24.998630999999932s
# Time spent compiling so far: 258.1128800000047
# Compilation time for circuit benchmarking/ibmq/sym10_262.qasm: 28.949083999999402s
# Time spent compiling so far: 287.0619640000041
# Compilation time for circuit benchmarking/ibmq/hwb8_113.qasm: 25.644740000000183s
# Time spent compiling so far: 312.70670400000427
# Compilation time for circuit benchmarking/ibmq/urf2_152.qasm: 28.757856000000174s
# Time spent compiling so far: 341.46456000000444
# Compilation time for circuit benchmarking/ibmq/urf3_279.qasm: 56.58784800000012s
# Time spent compiling so far: 398.05240800000456
# Compilation time for circuit benchmarking/ibmq/plus63mod4096_163.qasm: 55.02867800000013s
# Time spent compiling so far: 453.0810860000047
# Compilation time for circuit benchmarking/ibmq/urf5_158.qasm: 54.92023900000004s
# Time spent compiling so far: 508.0013250000047
# Compilation time for circuit benchmarking/ibmq/urf6_160.qasm: 76.02779399999963s
# Time spent compiling so far: 584.0291190000044
# Compilation time for circuit benchmarking/ibmq/urf1_149.qasm: 67.67557000000033s
# Time spent compiling so far: 651.7046890000047
# Compilation time for circuit benchmarking/ibmq/plus63mod8192_164.qasm: 89.26941500000021s
# Time spent compiling so far: 740.9741040000049
# Compilation time for circuit benchmarking/ibmq/hwb9_119.qasm: 83.31273800000008s
# Time spent compiling so far: 824.286842000005
# Compilation time for circuit benchmarking/ibmq/urf3_155.qasm: 161.91820299999972s
# Time spent compiling so far: 986.2050450000047
# Compilation time for circuit benchmarking/ibmq/ground_state_estimation_10.qasm: 144.61577699999998s
# Time spent compiling so far: 1130.8208220000047
# Compilation time for circuit benchmarking/ibmq/urf4_187.qasm: 193.86271099999976s
# Time spent compiling so far: 1324.6835330000044
#                                  Size out  Depth out  CX count out  \
# xor5_254.qasm                           9          7             5
# graycode6_47.qasm                       5          5             5
# ex1_226.qasm                            9          7             5
# 4gt11_84.qasm                          18         12             7
# 4mod5-v0_20.qasm                       21         14             9
# ex-1_166.qasm                          19         12             7
# 4mod5-v1_22.qasm                       23         15            10
# mod5d1_63.qasm                         24         17            11
# ham3_102.qasm                          20         14             9
# 4gt11_83.qasm                          26         19            12
# 4gt11_82.qasm                          34         25            15
# rd32-v0_66.qasm                        35         22            12
# alu-v0_27.qasm                         39         26            13
# 4mod5-v1_24.qasm                       37         24            11
# 4mod5-v0_19.qasm                       36         21            12
# mod5mils_65.qasm                       37         23            12
# rd32-v1_68.qasm                        37         23            12
# alu-v1_28.qasm                         40         27            14
# alu-v2_33.qasm                         39         24            13
# alu-v4_37.qasm                         39         26            13
# alu-v3_35.qasm                         39         26            13
# 3_17_13.qasm                           36         26            12
# alu-v1_29.qasm                         40         27            13
# miller_11.qasm                         50         30            17
# alu-v3_34.qasm                         56         37            18
# decod24-v2_43.qasm                     52         31            16
# decod24-v0_38.qasm                     53         32            16
# mod5d2_64.qasm                         57         38            20
# 4gt13_92.qasm                          67         44            21
# 4gt13-v1_93.qasm                       69         43            22
# 4mod5-v0_18.qasm                       73         44            21
# decod24-bdd_294.qasm                   76         43            24
# one-two-three-v2_100.qasm              71         44            25
# one-two-three-v3_101.qasm              73         46            24
# 4mod5-v1_23.qasm                       74         48            22
# 4mod5-bdd_287.qasm                     76         56            25
# rd32_270.qasm                          93         56            23
# 4gt5_75.qasm                           91         57            28
# alu-bdd_288.qasm                       90         57            28
# alu-v0_26.qasm                         96         71            31
# decod24-v1_41.qasm                     91         60            28
# rd53_138.qasm                         157        103            49
# 4gt5_76.qasm                           98         72            34
# 4gt13_91.qasm                         111         71            40
# cnt3-5_179.qasm                       244        114            70
# qft_10.qasm                           237        102            78
# 4gt13_90.qasm                         115         74            42
# alu-v4_36.qasm                        120         81            34
# mini_alu_305.qasm                     191         88            57
# ising_model_10.qasm                   480         70            90
# ising_model_16.qasm                   786         71           150
# ising_model_13.qasm                   633         71           120
# 4gt5_77.qasm                          137         88            43
# sys6-v0_111.qasm                      241        140            72
# one-two-three-v1_99.qasm              142         93            40
# one-two-three-v0_98.qasm              158         99            47
# decod24-v3_45.qasm                    157         97            44
# 4gt10-v1_81.qasm                      161        106            48
# aj-e11_165.qasm                       160        106            52
# 4mod7-v0_94.qasm                      175        114            51
# alu-v2_32.qasm                        178        120            55
# rd73_140.qasm                         277        179            80
# 4mod7-v1_96.qasm                      179        119            52
# 4gt4-v0_80.qasm                       199        131            61
# mod10_176.qasm                        192        133            58
# 0410184_169.qasm                      250        137            86
# qft_16.qasm                           622        196           176
# 4gt12-v0_88.qasm                      217        136            64
# rd84_142.qasm                         382        211           104
# rd53_311.qasm                         336        182            83
# 4_49_16.qasm                          237        161            72
# sym9_146.qasm                         390        226           113
# 4gt12-v1_89.qasm                      244        154            73
# 4gt12-v0_87.qasm                      274        179            86
# 4gt4-v0_79.qasm                       257        173            77
# hwb4_49.qasm                          252        180            78
# sym6_316.qasm                         325        201            89
# 4gt12-v0_86.qasm                      281        186            89
# 4gt4-v0_72.qasm                       274        172            76
# 4gt4-v0_78.qasm                       265        181            79
# mod10_171.qasm                        259        170            78
# 4gt4-v1_74.qasm                       294        187            81
# rd53_135.qasm                         341        222           104
# mini-alu_167.qasm                     310        194            86
# one-two-three-v0_97.qasm              309        195            87
# ham7_104.qasm                         364        246           104
# decod24-enable_126.qasm               374        248           111
# mod8-10_178.qasm                      372        239           107
# cnt3-5_180.qasm                       540        297           160
# ex3_229.qasm                          436        275           121
# 4gt4-v0_73.qasm                       440        307           133
# mod8-10_177.qasm                      503        341           158
# C17_204.qasm                          512        329           143
# alu-v2_31.qasm                        476        300           143
# rd53_131.qasm                         503        322           143
# alu-v2_30.qasm                        557        354           154
# mod5adder_127.qasm                    601        382           161
# rd53_133.qasm                         651        451           181
