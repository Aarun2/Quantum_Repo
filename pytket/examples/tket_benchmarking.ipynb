# %% [markdown]
# # tket benchmarking example

# %% [markdown]
# Warning: This notebook is now deprecated for versions from 0.2.0 onwards, and is not going to be updated in ongoing releases.
#
# The aim of this example is to show how to run the IBM benchmarking circuits through tket. You will need both `pytket` and `pytket_qiskit` installed from pip before running this turoial. You will also need `pandas` to capture the data.
#
# The benchmarking circuits originated from https://github.com/iic-jku/ibm_qx_mapping/tree/master/examples, but there is a copy in pytket in the "benchmarking" folder. The initial circuits are written in QASM, meaning that they must be converted to tket's internal representation via Qiskit. Using this script we will compile these circuits through tket and then print a table to terminal containing analysis of the circuits post-compilation.
#
# First, begin by importing qiskit and pytket.

# %%
import qiskit
import pytket

# %% [markdown]
# We need access to Qiskit's `QuantumCircuit` and the `circuit_to_dag` converter, which will allow us to take the original QASM and retrieve a Qiskit DAGCircuit. There is then a pytket method `dagcircuit_to_tk` to convert this DAGCircuit to tket's internal representation. We also need the pytket method `coupling_to_arc` to convert IBM's architectures to the tket `Architecture` class for the use of routing.

# %%
from qiskit import QuantumCircuit
from pytket.extensions.qiskit import IBMQBackend

from pytket.extensions.qiskit import qiskit_to_tk
from pytket.passes import PlacementPass, RoutingPass
from pytket.predicates import CompilationUnit
from pytket.routing import GraphPlacement

# %% [markdown]
# We need all of the required pytket equipment to allow us to perform clean-up transform passes, to route and to analyse the circuits. Lastly, we require the `pandas` module to hold our data, and
# `time` to benchmark compilation time per circuit.

# %% [markdown]
# The architectures used to benchmark for our routing paper were the IBMqx5 and IBMTokyo architectures. The architectures qx5 and Tokyo respectively are shown below (although the diagrams do not show the directedness of the coupling maps). These diagrams are from https://www.research.ibm.com/ibm-q/technology/devices/#ibmqx5. We will now define the coupling map representing both architectures. These will later be converted to directed graphs to be used by tket.
# ![alt text](IBMqx5Arc.png "Title")
# ![alt text](IBMTokyoArc.png "Title2")

# %%
from pytket.routing import Architecture, route
from pytket.transform import Transform
from pytket import OpType
from pytket import circuit
from pytket.circuit.display import render_circuit_jupyter
from pytket.routing import Placement
import pandas
import time

# %%
ibm_devices = {
    "ibmqx5": {"edges": [(1, 0), (1, 2), (2, 3), (3, 4), 
    (3, 14), (5, 4), (6, 5), (6, 7), (6, 11), (7, 10), 
    (8, 7), (9, 8), (9, 10), (11, 10), (12, 5), (12, 11), 
    (12, 13), (13, 4), (13, 14), (15, 0), (15, 2), (15, 14)],
    "nodes": 16},
    "ibmq_20_tokyo": {"edges": [(0, 1), (0, 5), (1, 2), (1, 6), (1, 7), (2, 3), (2, 6),
    (2, 7), (3, 4), (3, 8), (3, 9), (4, 8), (4, 9), (5, 6), (5, 10), (5, 11), (6, 7),
    (6, 10), (6, 11), (7, 8), (7, 12), (7, 13), (8, 9), (8, 12), (8, 13), (9, 14), (10, 11),
    (10, 15), (11, 12), (11, 16), (11, 17), (12, 13), (12, 16), (12, 17), (13, 14), (13, 18),
    (13, 19), (14, 18), (14, 19), (15, 16), (16, 17), (17, 18), (18, 19)], "nodes": 20},
    "Rochester" : {"edges": [(0, 1), (0, 5), (1, 2), (2, 3), (3, 4), (4, 6), (5, 9),
    (6, 13), (7, 8), (16, 7), (16, 19), (8, 9),  (9, 10), (10, 11), (11, 12), (12, 13), (13, 14), (14, 15), (11, 17),
    (15, 18), (18, 27), (19, 20), (20, 21), (21, 22), (22, 23), (17, 23), (23, 24), (24, 25), (25, 26), (26, 27),
    (21, 28), (28, 32), (25, 29), (29, 36), (30, 31), (31, 32), (32, 33), (33, 34), (34, 35), (35, 36), (36, 37), 
    (37, 38), (30, 39), (39, 42), (34, 40), (38, 41), (40, 46), (41, 50), (42, 43), (43, 44), (44, 45), 
    (45, 46), (46, 47), (47, 48), (48, 49), (49, 50), (48, 52), (44, 51)], "nodes": 53}
}

# %% [markdown]
# We shall now choose the device and create a directed graph for tket's routing to use.

# %%
device_name = 'ibmq_20_tokyo' ###Note: can also be ran using the Tokyo machine architecture
                                       ###      or with a user-defined coupling map
coupling_map = ibm_devices[device_name]["edges"]
directed_arc = Architecture(coupling_map)

# %% [markdown]
# We now define a method which takes in (1) a QASM file and (2) a directed graph architecture; it returns analysis of the circuit after our transform passes and routing procedure have been completed. It will also print out to terminal the time taken for all the transformations and routing to finish. Changing which optimisations are run in this method will trade off quality of the ouputs for time taken. For example, removing all optimisation passes and just running the routing procedure will give the fastest run time but may leave some redundant gates in the final circuit.

# %%
def getStats(filename, directed_arc):
    qc = QuantumCircuit.from_qasm_file(filename)
    tkcirc = qiskit_to_tk(qc)
    #cu = CompilationUnit(tkcirc)
    start_time = time.process_time()
    PlacementPass(GraphPlacement(directed_arc)).apply(tkcirc)
    RoutingPass(directed_arc).apply(tkcirc)
    #while (~DirectednessPredicate({}).verify(tkcirc)):
      #  RebaseTket().apply(tkcirc)
    # print(cu.initial_map)
    # print(cu.final_map)
    
    time_elapsed = time.process_time() - start_time
    
    print("Compilation time for circuit " + str(filename) + ": " + str(time_elapsed) + "s")
    
    #render_circuit_jupyter(tkcirc)
    if tkcirc.n_gates==0:
        return [0,0,0,0,0]
    ###Returns: [number of vertices, circuit depth, nubmer of CX gates, number of parallel slices of CX gates]
    return [tkcirc.n_gates, tkcirc.depth(), tkcirc.n_gates_of_type(OpType.CX), 
            tkcirc.depth_by_type(OpType.CX), time_elapsed]
    ###Note: the raw number of vertices in the circuits and the raw depth 
    ###      need to have the i/o vertices removed for fair comparisons

# %% [markdown]
# Lastly, we generate the table of input QASM filenames from a csv file using `pandas` and run the circuits through our compiler. The results are printed to terminal by default.

# %%
test_table = pandas.read_csv("benchmarking/IBMQConfig.csv",index_col=0)
test_table = test_table.sort_values(by='Depth in')

stat_table = pandas.DataFrame({})
total_time = 0

for i, (index, row) in enumerate(test_table.iterrows()):
    filename = row['Filename']
    new_stats = getStats(filename, directed_arc)
    total_time += new_stats[4] ###
    print("Time spent compiling so far: " + str(total_time))
    new_table_row = pandas.DataFrame.from_dict({index : new_stats}, 
    orient='index', columns=['Size out', 'Depth out', 'CX count out', 'CX depth out','Runtime'])
    stat_table = stat_table.append(new_table_row)

#stat_table.to_csv("BenchmarkTket.csv") ###Note: uncomment this line to print table to csv.
with pandas.option_context('display.max_rows', None):
    print(stat_table)
# Out:
# Compilation time for circuit benchmarking/ibmq/xor5_254.qasm: 0.0343239999999998s
# Time spent compiling so far: 0.0343239999999998
# Compilation time for circuit benchmarking/ibmq/graycode6_47.qasm: 0.06614999999999949s
# Time spent compiling so far: 0.10047399999999929
# Compilation time for circuit benchmarking/ibmq/ex1_226.qasm: 0.03374000000000077s
# Time spent compiling so far: 0.13421400000000006
# Compilation time for circuit benchmarking/ibmq/4gt11_84.qasm: 0.007169999999999455s
# Time spent compiling so far: 0.1413839999999995
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_20.qasm: 0.01126899999999953s
# Time spent compiling so far: 0.15265299999999904
# Compilation time for circuit benchmarking/ibmq/ex-1_166.qasm: 0.006577000000000055s
# Time spent compiling so far: 0.1592299999999991
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_22.qasm: 0.011538999999999966s
# Time spent compiling so far: 0.17076899999999906
# Compilation time for circuit benchmarking/ibmq/mod5d1_63.qasm: 0.012345000000000717s
# Time spent compiling so far: 0.18311399999999978
# Compilation time for circuit benchmarking/ibmq/ham3_102.qasm: 0.006168000000000617s
# Time spent compiling so far: 0.1892820000000004
# Compilation time for circuit benchmarking/ibmq/4gt11_83.qasm: 0.015591999999999828s
# Time spent compiling so far: 0.20487400000000022
# Compilation time for circuit benchmarking/ibmq/4gt11_82.qasm: 0.016672999999999938s
# Time spent compiling so far: 0.22154700000000016
# Compilation time for circuit benchmarking/ibmq/rd32-v0_66.qasm: 0.007395999999999958s
# Time spent compiling so far: 0.22894300000000012
# Compilation time for circuit benchmarking/ibmq/alu-v0_27.qasm: 0.011214999999999975s
# Time spent compiling so far: 0.2401580000000001
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_24.qasm: 0.06377900000000025s
# Time spent compiling so far: 0.30393700000000035
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_19.qasm: 0.00914500000000018s
# Time spent compiling so far: 0.3130820000000005
# Compilation time for circuit benchmarking/ibmq/mod5mils_65.qasm: 0.008922999999999348s
# Time spent compiling so far: 0.3220049999999999
# Compilation time for circuit benchmarking/ibmq/rd32-v1_68.qasm: 0.0098969999999996s
# Time spent compiling so far: 0.3319019999999995
# Compilation time for circuit benchmarking/ibmq/alu-v1_28.qasm: 0.010195000000000398s
# Time spent compiling so far: 0.3420969999999999
# Compilation time for circuit benchmarking/ibmq/alu-v2_33.qasm: 0.012824000000000169s
# Time spent compiling so far: 0.35492100000000004
# Compilation time for circuit benchmarking/ibmq/alu-v4_37.qasm: 0.011949000000000431s
# Time spent compiling so far: 0.3668700000000005
# Compilation time for circuit benchmarking/ibmq/alu-v3_35.qasm: 0.014113000000000042s
# Time spent compiling so far: 0.3809830000000005
# Compilation time for circuit benchmarking/ibmq/3_17_13.qasm: 0.006649999999999601s
# Time spent compiling so far: 0.3876330000000001
# Compilation time for circuit benchmarking/ibmq/alu-v1_29.qasm: 0.009790999999999883s
# Time spent compiling so far: 0.397424
# Compilation time for circuit benchmarking/ibmq/miller_11.qasm: 0.007454000000000072s
# Time spent compiling so far: 0.40487800000000007
# Compilation time for circuit benchmarking/ibmq/alu-v3_34.qasm: 0.01036500000000018s
# Time spent compiling so far: 0.41524300000000025
# Compilation time for circuit benchmarking/ibmq/decod24-v2_43.qasm: 0.008513000000000659s
# Time spent compiling so far: 0.4237560000000009
# Compilation time for circuit benchmarking/ibmq/decod24-v0_38.qasm: 0.00864299999999929s
# Time spent compiling so far: 0.4323990000000002
# Compilation time for circuit benchmarking/ibmq/mod5d2_64.qasm: 0.018295999999999424s
# Time spent compiling so far: 0.4506949999999996
# Compilation time for circuit benchmarking/ibmq/4gt13_92.qasm: 0.07365700000000075s
# Time spent compiling so far: 0.5243520000000004
# Compilation time for circuit benchmarking/ibmq/4gt13-v1_93.qasm: 0.07029500000000066s
# Time spent compiling so far: 0.594647000000001
# Compilation time for circuit benchmarking/ibmq/4mod5-v0_18.qasm: 0.013389999999999347s
# Time spent compiling so far: 0.6080370000000004
# Compilation time for circuit benchmarking/ibmq/decod24-bdd_294.qasm: 0.016319000000000194s
# Time spent compiling so far: 0.6243560000000006
# Compilation time for circuit benchmarking/ibmq/one-two-three-v2_100.qasm: 0.022382000000000346s
# Time spent compiling so far: 0.6467380000000009
# Compilation time for circuit benchmarking/ibmq/one-two-three-v3_101.qasm: 0.017306000000000488s
# Time spent compiling so far: 0.6640440000000014
# Compilation time for circuit benchmarking/ibmq/4mod5-v1_23.qasm: 0.017679999999999474s
# Time spent compiling so far: 0.6817240000000009
# Compilation time for circuit benchmarking/ibmq/4mod5-bdd_287.qasm: 0.04747900000000005s
# Time spent compiling so far: 0.7292030000000009
# Compilation time for circuit benchmarking/ibmq/rd32_270.qasm: 0.018927999999999834s
# Time spent compiling so far: 0.7481310000000008
# Compilation time for circuit benchmarking/ibmq/4gt5_75.qasm: 0.028026999999999802s
# Time spent compiling so far: 0.7761580000000006
# Compilation time for circuit benchmarking/ibmq/alu-bdd_288.qasm: 0.09946300000000008s
# Time spent compiling so far: 0.8756210000000006
# Compilation time for circuit benchmarking/ibmq/alu-v0_26.qasm: 0.02937700000000021s
# Time spent compiling so far: 0.9049980000000009
# Compilation time for circuit benchmarking/ibmq/decod24-v1_41.qasm: 0.08625900000000009s
# Time spent compiling so far: 0.9912570000000009
# Compilation time for circuit benchmarking/ibmq/rd53_138.qasm: 0.04083499999999951s
# Time spent compiling so far: 1.0320920000000005
# Compilation time for circuit benchmarking/ibmq/4gt5_76.qasm: 0.04806199999999983s
# Time spent compiling so far: 1.0801540000000003
# Compilation time for circuit benchmarking/ibmq/4gt13_91.qasm: 0.030778999999999s
# Time spent compiling so far: 1.1109329999999993
# Compilation time for circuit benchmarking/ibmq/cnt3-5_179.qasm: 0.24693199999999926s
# Time spent compiling so far: 1.3578649999999985
# Compilation time for circuit benchmarking/ibmq/qft_10.qasm: 0.05444699999999969s
# Time spent compiling so far: 1.4123119999999982
# Compilation time for circuit benchmarking/ibmq/4gt13_90.qasm: 0.03384199999999993s
# Time spent compiling so far: 1.4461539999999982
# Compilation time for circuit benchmarking/ibmq/alu-v4_36.qasm: 0.1038730000000001s
# Time spent compiling so far: 1.5500269999999983
# Compilation time for circuit benchmarking/ibmq/mini_alu_305.qasm: 0.10453500000000027s
# Time spent compiling so far: 1.6545619999999985
# Compilation time for circuit benchmarking/ibmq/ising_model_10.qasm: 0.11906499999999909s
# Time spent compiling so far: 1.7736269999999976
# Compilation time for circuit benchmarking/ibmq/ising_model_16.qasm: 0.19238299999999953s
# Time spent compiling so far: 1.9660099999999971
# Compilation time for circuit benchmarking/ibmq/ising_model_13.qasm: 0.1496859999999991s
# Time spent compiling so far: 2.1156959999999962
# Compilation time for circuit benchmarking/ibmq/4gt5_77.qasm: 0.04099599999999981s
# Time spent compiling so far: 2.156691999999996
# Compilation time for circuit benchmarking/ibmq/sys6-v0_111.qasm: 0.07169299999999978s
# Time spent compiling so far: 2.228384999999996
# Compilation time for circuit benchmarking/ibmq/one-two-three-v1_99.qasm: 0.11367399999999961s
# Time spent compiling so far: 2.3420589999999955
# Compilation time for circuit benchmarking/ibmq/one-two-three-v0_98.qasm: 0.12322099999999914s
# Time spent compiling so far: 2.4652799999999946
# Compilation time for circuit benchmarking/ibmq/decod24-v3_45.qasm: 0.11215400000000031s
# Time spent compiling so far: 2.577433999999995
# Compilation time for circuit benchmarking/ibmq/4gt10-v1_81.qasm: 0.11783599999999872s
# Time spent compiling so far: 2.6952699999999936
# Compilation time for circuit benchmarking/ibmq/aj-e11_165.qasm: 0.07491599999999998s
# Time spent compiling so far: 2.7701859999999936
# Compilation time for circuit benchmarking/ibmq/4mod7-v0_94.qasm: 0.10329699999999953s
# Time spent compiling so far: 2.873482999999993
# Compilation time for circuit benchmarking/ibmq/alu-v2_32.qasm: 0.03831899999999955s
# Time spent compiling so far: 2.9118019999999927
# Compilation time for circuit benchmarking/ibmq/rd73_140.qasm: 0.08933999999999997s
# Time spent compiling so far: 3.0011419999999926
# Compilation time for circuit benchmarking/ibmq/4mod7-v1_96.qasm: 0.04264599999999952s
# Time spent compiling so far: 3.043787999999992
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_80.qasm: 0.07242199999999954s
# Time spent compiling so far: 3.1162099999999917
# Compilation time for circuit benchmarking/ibmq/mod10_176.qasm: 0.1484179999999995s
# Time spent compiling so far: 3.264627999999991
# Compilation time for circuit benchmarking/ibmq/0410184_169.qasm: 0.3294950000000014s
# Time spent compiling so far: 3.5941229999999926
# Compilation time for circuit benchmarking/ibmq/qft_16.qasm: 0.27593200000000095s
# Time spent compiling so far: 3.8700549999999936
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_88.qasm: 0.08607800000000054s
# Time spent compiling so far: 3.956132999999994
# Compilation time for circuit benchmarking/ibmq/rd84_142.qasm: 0.1719810000000006s
# Time spent compiling so far: 4.128113999999995
# Compilation time for circuit benchmarking/ibmq/rd53_311.qasm: 0.18427300000000102s
# Time spent compiling so far: 4.312386999999996
# Compilation time for circuit benchmarking/ibmq/4_49_16.qasm: 0.15261000000000102s
# Time spent compiling so far: 4.464996999999997
# Compilation time for circuit benchmarking/ibmq/sym9_146.qasm: 0.1894240000000007s
# Time spent compiling so far: 4.6544209999999975
# Compilation time for circuit benchmarking/ibmq/4gt12-v1_89.qasm: 0.1516730000000006s
# Time spent compiling so far: 4.806093999999998
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_87.qasm: 0.11514100000000127s
# Time spent compiling so far: 4.921234999999999
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_79.qasm: 0.1190269999999991s
# Time spent compiling so far: 5.0402619999999985
# Compilation time for circuit benchmarking/ibmq/hwb4_49.qasm: 0.07215499999999864s
# Time spent compiling so far: 5.112416999999997
# Compilation time for circuit benchmarking/ibmq/sym6_316.qasm: 0.2309960000000011s
# Time spent compiling so far: 5.343412999999998
# Compilation time for circuit benchmarking/ibmq/4gt12-v0_86.qasm: 0.12218199999999868s
# Time spent compiling so far: 5.465594999999997
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_72.qasm: 0.11904000000000181s
# Time spent compiling so far: 5.584634999999999
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_78.qasm: 0.13044100000000114s
# Time spent compiling so far: 5.715076
# Compilation time for circuit benchmarking/ibmq/mod10_171.qasm: 0.05992900000000034s
# Time spent compiling so far: 5.775005
# Compilation time for circuit benchmarking/ibmq/4gt4-v1_74.qasm: 0.08616899999999816s
# Time spent compiling so far: 5.861173999999998
# Compilation time for circuit benchmarking/ibmq/rd53_135.qasm: 0.12094100000000196s
# Time spent compiling so far: 5.982115
# Compilation time for circuit benchmarking/ibmq/mini-alu_167.qasm: 0.11901100000000042s
# Time spent compiling so far: 6.101126000000001
# Compilation time for circuit benchmarking/ibmq/one-two-three-v0_97.qasm: 0.23694500000000218s
# Time spent compiling so far: 6.338071000000003
# Compilation time for circuit benchmarking/ibmq/ham7_104.qasm: 0.20497699999999952s
# Time spent compiling so far: 6.543048000000002
# Compilation time for circuit benchmarking/ibmq/decod24-enable_126.qasm: 0.2250179999999986s
# Time spent compiling so far: 6.768066000000001
# Compilation time for circuit benchmarking/ibmq/mod8-10_178.qasm: 0.1871579999999966s
# Time spent compiling so far: 6.955223999999998
# Compilation time for circuit benchmarking/ibmq/cnt3-5_180.qasm: 0.5092539999999985s
# Time spent compiling so far: 7.464477999999996
# Compilation time for circuit benchmarking/ibmq/ex3_229.qasm: 0.22024899999999903s
# Time spent compiling so far: 7.684726999999995
# Compilation time for circuit benchmarking/ibmq/4gt4-v0_73.qasm: 0.1848610000000015s
# Time spent compiling so far: 7.869587999999997
# Compilation time for circuit benchmarking/ibmq/mod8-10_177.qasm: 0.2112969999999983s
# Time spent compiling so far: 8.080884999999995
# Compilation time for circuit benchmarking/ibmq/C17_204.qasm: 0.2364999999999995s
# Time spent compiling so far: 8.317384999999994
# Compilation time for circuit benchmarking/ibmq/alu-v2_31.qasm: 0.11337599999999881s
# Time spent compiling so far: 8.430760999999993
# Compilation time for circuit benchmarking/ibmq/rd53_131.qasm: 0.4426029999999983s
# Time spent compiling so far: 8.873363999999992
# Compilation time for circuit benchmarking/ibmq/alu-v2_30.qasm: 0.28296800000000033s
# Time spent compiling so far: 9.156331999999992
# Compilation time for circuit benchmarking/ibmq/mod5adder_127.qasm: 0.23959100000000078s
# Time spent compiling so far: 9.395922999999993
# Compilation time for circuit benchmarking/ibmq/rd53_133.qasm: 0.3708349999999996s
# Time spent compiling so far: 9.766757999999992
# Compilation time for circuit benchmarking/ibmq/cm82a_208.qasm: 0.5859899999999989s
# Time spent compiling so far: 10.352747999999991
# Compilation time for circuit benchmarking/ibmq/majority_239.qasm: 0.3806839999999987s
# Time spent compiling so far: 10.73343199999999
# Compilation time for circuit benchmarking/ibmq/ex2_227.qasm: 0.4088700000000003s
# Time spent compiling so far: 11.14230199999999
# Compilation time for circuit benchmarking/ibmq/sf_276.qasm: 0.37319499999999906s
# Time spent compiling so far: 11.51549699999999
# Compilation time for circuit benchmarking/ibmq/sf_274.qasm: 0.37152599999999936s
# Time spent compiling so far: 11.887022999999989
# Compilation time for circuit benchmarking/ibmq/con1_216.qasm: 0.9159620000000004s
# Time spent compiling so far: 12.802984999999989
# Compilation time for circuit benchmarking/ibmq/wim_266.qasm: 0.9034259999999996s
# Time spent compiling so far: 13.706410999999989
# Compilation time for circuit benchmarking/ibmq/rd53_130.qasm: 0.6729020000000006s
# Time spent compiling so far: 14.37931299999999
# Compilation time for circuit benchmarking/ibmq/f2_232.qasm: 0.9693060000000031s
# Time spent compiling so far: 15.348618999999992
# Compilation time for circuit benchmarking/ibmq/cm152a_212.qasm: 0.6709000000000032s
# Time spent compiling so far: 16.019518999999995
# Compilation time for circuit benchmarking/ibmq/rd53_251.qasm: 0.7095219999999998s
# Time spent compiling so far: 16.729040999999995
# Compilation time for circuit benchmarking/ibmq/hwb5_53.qasm: 0.7947360000000003s
# Time spent compiling so far: 17.523776999999995
# Compilation time for circuit benchmarking/ibmq/cm42a_207.qasm: 1.141247s
# Time spent compiling so far: 18.665023999999995
# Compilation time for circuit benchmarking/ibmq/pm1_249.qasm: 1.0703450000000032s
# Time spent compiling so far: 19.735369
# Compilation time for circuit benchmarking/ibmq/dc1_220.qasm: 1.4026890000000023s
# Time spent compiling so far: 21.138058
# Compilation time for circuit benchmarking/ibmq/squar5_261.qasm: 1.9078879999999998s
# Time spent compiling so far: 23.045946
# Compilation time for circuit benchmarking/ibmq/z4_268.qasm: 2.4645460000000057s
# Time spent compiling so far: 25.510492000000006
# Compilation time for circuit benchmarking/ibmq/sqrt8_260.qasm: 2.736571000000005s
# Time spent compiling so far: 28.24706300000001
# Compilation time for circuit benchmarking/ibmq/radd_250.qasm: 2.3276719999999997s
# Time spent compiling so far: 30.57473500000001
# Compilation time for circuit benchmarking/ibmq/adr4_197.qasm: 3.094777999999998s
# Time spent compiling so far: 33.66951300000001
# Compilation time for circuit benchmarking/ibmq/sym6_145.qasm: 1.9724939999999975s
# Time spent compiling so far: 35.64200700000001
# Compilation time for circuit benchmarking/ibmq/misex1_241.qasm: 3.8961690000000004s
# Time spent compiling so far: 39.53817600000001
# Compilation time for circuit benchmarking/ibmq/rd73_252.qasm: 4.306106s
# Time spent compiling so far: 43.84428200000001
# Compilation time for circuit benchmarking/ibmq/cycle10_2_110.qasm: 4.652490999999998s
# Time spent compiling so far: 48.496773000000005
# Compilation time for circuit benchmarking/ibmq/hwb6_56.qasm: 3.0623580000000032s
# Time spent compiling so far: 51.55913100000001
# Compilation time for circuit benchmarking/ibmq/square_root_7.qasm: 5.904098000000005s
# Time spent compiling so far: 57.46322900000001
# Compilation time for circuit benchmarking/ibmq/ham15_107.qasm: 7.1807779999999894s
# Time spent compiling so far: 64.644007
# Compilation time for circuit benchmarking/ibmq/dc2_222.qasm: 8.945385000000002s
# Time spent compiling so far: 73.589392
# Compilation time for circuit benchmarking/ibmq/sqn_258.qasm: 8.791108000000008s
# Time spent compiling so far: 82.38050000000001
# Compilation time for circuit benchmarking/ibmq/inc_237.qasm: 9.564092000000002s
# Time spent compiling so far: 91.94459200000001
# Compilation time for circuit benchmarking/ibmq/cm85a_209.qasm: 9.48139599999999s
# Time spent compiling so far: 101.425988
# Compilation time for circuit benchmarking/ibmq/rd84_253.qasm: 11.758989000000014s
# Time spent compiling so far: 113.18497700000002
# Compilation time for circuit benchmarking/ibmq/co14_215.qasm: 22.496667000000002s
# Time spent compiling so far: 135.681644
# Compilation time for circuit benchmarking/ibmq/root_255.qasm: 14.566260999999997s
# Time spent compiling so far: 150.247905
# Compilation time for circuit benchmarking/ibmq/mlp4_245.qasm: 17.986597999999987s
# Time spent compiling so far: 168.234503
# Compilation time for circuit benchmarking/ibmq/urf2_277.qasm: 12.066460000000006s
# Time spent compiling so far: 180.300963
# Compilation time for circuit benchmarking/ibmq/sym9_148.qasm: 19.858160999999996s
# Time spent compiling so far: 200.159124
# Compilation time for circuit benchmarking/ibmq/life_238.qasm: 23.101541999999995s
# Time spent compiling so far: 223.260666
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/9_/z9c5t97d2mjfpjbp5_5gz7hw0000gp/T/ipykernel_35610/3333334003.py in <module>
#       7 for i, (index, row) in enumerate(test_table.iterrows()):
#       8     filename = row['Filename']
# ----> 9     new_stats = getStats(filename, directed_arc)
#      10     total_time += new_stats[4] ###
#      11     print("Time spent compiling so far: " + str(total_time))
#
# /var/folders/9_/z9c5t97d2mjfpjbp5_5gz7hw0000gp/T/ipykernel_35610/724960264.py in getStats(filename, directed_arc)
#       5     start_time = time.process_time()
#       6     PlacementPass(GraphPlacement(directed_arc)).apply(tkcirc)
# ----> 7     RoutingPass(directed_arc).apply(tkcirc)
#       8     #while (~DirectednessPredicate({}).verify(tkcirc)):
#       9       #  RebaseTket().apply(tkcirc)
#
# KeyboardInterrupt:
